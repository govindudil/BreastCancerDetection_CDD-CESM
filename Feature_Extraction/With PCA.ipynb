# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # CC_CM

# %%
test_df = pd.read_csv('../dataset/cc_cm/test_dataset.csv', header=0)
train_df = pd.read_csv('../dataset/cc_cm/train_dataset.csv', header=0)

# %%
col_names = train_df.columns.values    

nominal_idx = [0, 124]
binary_idx = [123, 121, 122]
numeric_idx = list(set(range(125)).difference(nominal_idx).difference(binary_idx))

numeric_cols = col_names[numeric_idx].tolist()   # The columns that have numerical features

y_train = train_df['isCancerous']
y_test = test_df['isCancerous']

# In this case, we are only going to use the numeric columns for our predictions
X_train = train_df[numeric_cols]   
X_test = test_df[numeric_cols]

# %%
# Create a PCA instance with randomized solver and use all available CPU cores
pca = PCA(n_components=20, svd_solver='randomized')

# Fit and transform the data
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Plot the first two principal components
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('PCA of Dataset')
plt.show()

# %%
# Create a Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)

# %%
# Train the classifier
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
# Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Print the accuracy
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9275972485768501

# %%
# Print the accuracy
print("Accuracy:", metrics.balanced_accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7452103034357713

# %%
# Print the accuracy
print("Accuracy:", metrics.f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.6474664356864444

# %%
# Print the accuracy
print("Accuracy:", metrics.roc_auc_score(y_test, y_pred))
# Out:
# Accuracy: 0.7452103034357712

# %%
# Print the accuracy
print("Accuracy:", metrics.precision_score(y_test, y_pred))
# Out:
# Accuracy: 0.9320448877805486

# %%
# Print the accuracy
print("Accuracy:", metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.4960185799601858

# %%
# Print the accuracy
print("Accuracy:", metrics.top_k_accuracy_score(y_test, y_pred, k=1))
# Out:
# Accuracy: 0.9275972485768501

# %%
# Confusion matrix
confusionMatrix = metrics.confusion_matrix(y_test, y_pred, labels=clf.classes_)
print("\nConfusion matrix:")
print(confusionMatrix)
# Out:
# Confusion matrix:
# [[58087   327]
#  [ 4557  4485]]

# %%
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = confusionMatrix, display_labels = clf.classes_)
disp.plot()
plt.title("Confusion matrix after feature reduction - (CC_CM)")
plt.show()

# %% [markdown]
# # CC_DM

# %%
test_df = pd.read_csv('../dataset/cc_dm/test_dataset.csv', header=0)
train_df = pd.read_csv('../dataset/cc_dm/train_dataset.csv', header=0)

# %%
col_names = train_df.columns.values    

nominal_idx = [0, 124]
binary_idx = [123, 121, 122]
numeric_idx = list(set(range(125)).difference(nominal_idx).difference(binary_idx))

numeric_cols = col_names[numeric_idx].tolist()   # The columns that have numerical features

y_train = train_df['isCancerous']
y_test = test_df['isCancerous']

# In this case, we are only going to use the numeric columns for our predictions
X_train = train_df[numeric_cols]   
X_test = test_df[numeric_cols]

# %%
# Create a PCA instance with randomized solver and use all available CPU cores
pca = PCA(n_components=25, svd_solver='randomized')

# Fit and transform the data
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Create a Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)

# %%
# Train the classifier
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
# Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Print the accuracy
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9012222751345658

# %%
# Print the accuracy
print("Accuracy:", metrics.balanced_accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.750747211148879

# %%
# Print the accuracy
print("Accuracy:", metrics.f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.6551810991889577

# %%
# Print the accuracy
print("Accuracy:", metrics.roc_auc_score(y_test, y_pred))
# Out:
# Accuracy: 0.750747211148879

# %%
# Print the accuracy
print("Accuracy:", metrics.precision_score(y_test, y_pred))
# Out:
# Accuracy: 0.9044506258692628

# %%
# Print the accuracy
print("Accuracy:", metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.5136245162309454

# %%
# Print the accuracy
print("Accuracy:", metrics.top_k_accuracy_score(y_test, y_pred, k=1))
# Out:
# Accuracy: 0.9012222751345658

# %%
# Confusion matrix
confusionMatrix = metrics.confusion_matrix(y_test, y_pred, labels=clf.classes_)
print("\nConfusion matrix:")
print(confusionMatrix)
# Out:
# Confusion matrix:
# [[55949   687]
#  [ 6158  6503]]

# %%
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = confusionMatrix, display_labels = clf.classes_)
disp.plot()
plt.title("Confusion matrix after feature reduction - (CC_DM)")
plt.show()

# %% [markdown]
# # MLO_CM

# %%
test_df = pd.read_csv('../dataset/mlo_cm/test_dataset.csv', header=0)
train_df = pd.read_csv('../dataset/mlo_cm/train_dataset.csv', header=0)

# %%
col_names = train_df.columns.values    

nominal_idx = [0, 124]
binary_idx = [123, 121, 122]
numeric_idx = list(set(range(125)).difference(nominal_idx).difference(binary_idx))

numeric_cols = col_names[numeric_idx].tolist()   # The columns that have numerical features

y_train = train_df['isCancerous']
y_test = test_df['isCancerous']

# In this case, we are only going to use the numeric columns for our predictions
X_train = train_df[numeric_cols]   
X_test = test_df[numeric_cols]

# %%
# Create a PCA instance with randomized solver and use all available CPU cores
pca = PCA(n_components=20, svd_solver='randomized')

# Fit and transform the data
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Create a Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)

# %%
# Train the classifier
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
# Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Print the accuracy
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9264940083022217

# %%
# Print the accuracy
print("Accuracy:", metrics.balanced_accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7476183021024427

# %%
# Print the accuracy
print("Accuracy:", metrics.f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.6504872447396188

# %%
# Print the accuracy
print("Accuracy:", metrics.roc_auc_score(y_test, y_pred))
# Out:
# Accuracy: 0.7476183021024426

# %%
# Print the accuracy
print("Accuracy:", metrics.precision_score(y_test, y_pred))
# Out:
# Accuracy: 0.9248146840804801

# %%
# Print the accuracy
print("Accuracy:", metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.501675442795596

# %%
# Print the accuracy
print("Accuracy:", metrics.top_k_accuracy_score(y_test, y_pred, k=1))
# Out:
# Accuracy: 0.9264940083022217

# %%
# Confusion matrix
confusionMatrix = metrics.confusion_matrix(y_test, y_pred, labels=clf.classes_)
print("\nConfusion matrix:")
print(confusionMatrix)
# Out:
# Confusion matrix:
# [[65735   426]
#  [ 5205  5240]]

# %%
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = confusionMatrix, display_labels = clf.classes_)
disp.plot()
plt.title("Confusion matrix after feature reduction - (MLO_CM)")
plt.show()

# %% [markdown]
# # MLO_DM

# %%
test_df = pd.read_csv('../dataset/mlo_dm/test_dataset.csv', header=0)
train_df = pd.read_csv('../dataset/mlo_dm/train_dataset.csv', header=0)

# %%
col_names = train_df.columns.values    

nominal_idx = [0, 124]
binary_idx = [123, 121, 122]
numeric_idx = list(set(range(125)).difference(nominal_idx).difference(binary_idx))

numeric_cols = col_names[numeric_idx].tolist()   # The columns that have numerical features

y_train = train_df['isCancerous']
y_test = test_df['isCancerous']

# In this case, we are only going to use the numeric columns for our predictions
X_train = train_df[numeric_cols]   
X_test = test_df[numeric_cols]

# %%
# Create a PCA instance with randomized solver and use all available CPU cores
pca = PCA(n_components=50, svd_solver='randomized')

# Fit and transform the data
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Create a Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)

# %%
# Train the classifier
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
# Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Print the accuracy
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8945015220700152

# %%
# Print the accuracy
print("Accuracy:", metrics.balanced_accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6948513175446648

# %%
# Print the accuracy
print("Accuracy:", metrics.f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.5526937481993661

# %%
# Print the accuracy
print("Accuracy:", metrics.roc_auc_score(y_test, y_pred))
# Out:
# Accuracy: 0.6948513175446648

# %%
# Print the accuracy
print("Accuracy:", metrics.precision_score(y_test, y_pred))
# Out:
# Accuracy: 0.9043937393927965

# %%
# Print the accuracy
print("Accuracy:", metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.3979422502489213

# %%
# Print the accuracy
print("Accuracy:", metrics.top_k_accuracy_score(y_test, y_pred, k=1))
# Out:
# Accuracy: 0.8945015220700152

# %%
# Confusion matrix
confusionMatrix = metrics.confusion_matrix(y_test, y_pred, labels=clf.classes_)
print("\nConfusion matrix:")
print(confusionMatrix)
# Out:
# Confusion matrix:
# [[61025   507]
#  [ 7256  4796]]

# %%
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = confusionMatrix, display_labels = clf.classes_)
disp.plot()
plt.title("Confusion matrix after feature reduction - (MLO_DM)")
plt.show()
